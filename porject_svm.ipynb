# %%
import pandas as pd 
import numpy as np
import plotly.express as px
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import validation_curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs
from sklearn.datasets import make_circles
#creating 40 separable points
X,y = make_circles(500,factor=0.5,noise=0.05)
#fit the model, codn't reqularize for illustation purposes
clf = svm.SVC(kernel = 'rbf', C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1], c =y, s = 30,cmap=plt.cm.Paired)
#plt.show()
#plt the decision function
ax = plt.gca()# shib -> finding axes
xlim = ax.get_xlim()#show the start point to the end point 
ylim = ax.get_ylim()
print(xlim)
print(ylim)
#create gird to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)#create 30 part from start poiont to end point
yy = np.linspace(ylim[0], ylim[1], 30)
# print(xx)
# print(yy)
YY, XX = np.meshgrid(yy, xx)#create matric -> like a chess
print(XX[0])
print(YY[0])
xy = np.vstack([XX.ravel(),YY.ravel()]).T#compine all of them (1,1),(1,2)
Z = clf.decision_function(xy).reshape(XX.shape)
#plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1],alpha=0.5, linestyles=['--','-','--'])
#plot support vectors
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1], s=100, linewidth = 1, facecolors = 'none')
plt.show()
# Out:
# (-1.216786384966363, 1.2193380734598593)
# (-1.2227456384362136, 1.2019438559898268)
# [-1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638
#  -1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638
#  -1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638
#  -1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638
#  -1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638 -1.21678638]
# [-1.22274564 -1.13913566 -1.05552567 -0.97191569 -0.88830571 -0.80469573
#  -0.72108574 -0.63747576 -0.55386578 -0.4702558  -0.38664581 -0.30303583
#  -0.21942585 -0.13581587 -0.05220588  0.0314041   0.11501408  0.19862407
#   0.28223405  0.36584403  0.44945401  0.533064    0.61667398  0.70028396
#   0.78389394  0.86750393  0.95111391  1.03472389  1.11833387  1.20194386]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs
from sklearn.datasets import make_circles
from sklearn.datasets import make_moons
#creating 40 separable points
X,y = make_moons(1000,noise=0.07)
#fit the model, codn't reqularize for illustation purposes
clf = svm.SVC(kernel = 'rbf', C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1], c =y, s = 30,cmap=plt.cm.Paired)
#plt.show()
#plt the decision function
ax = plt.gca()# shib -> finding axes
xlim = ax.get_xlim()#show the start point to the end point 
ylim = ax.get_ylim()
print(xlim)
print(ylim)
#create gird to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)#create 30 part from start poiont to end point
yy = np.linspace(ylim[0], ylim[1], 30)
# print(xx)
# print(yy)
YY, XX = np.meshgrid(yy, xx)#create matric -> like a chess
print(XX[0])
print(YY[0])
xy = np.vstack([XX.ravel(),YY.ravel()]).T#compine all of them (1,1),(1,2)
Z = clf.decision_function(xy).reshape(XX.shape)
#plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1],alpha=0.5, linestyles=['--','-','--'])
#plot support vectors
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1], s=100, linewidth = 1, facecolors = 'none')
plt.show()
# Out:
# (-1.3098243686935187, 2.2468818962522623)
# (-0.8252642153252596, 1.2406660258378512)
# [-1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437
#  -1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437
#  -1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437
#  -1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437
#  -1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437 -1.30982437]
# [-0.82526422 -0.75402524 -0.68278627 -0.61154729 -0.54030832 -0.46906935
#  -0.39783037 -0.3265914  -0.25535242 -0.18411345 -0.11287448 -0.0416355
#   0.02960347  0.10084244  0.17208142  0.24332039  0.31455937  0.38579834
#   0.45703731  0.52827629  0.59951526  0.67075424  0.74199321  0.81323218
#   0.88447116  0.95571013  1.0269491   1.09818808  1.16942705  1.24066603]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs
from sklearn.datasets import make_circles
from sklearn.datasets import make_moons
#creating 40 separable points
X,y = make_blobs(centers=2,n_samples=200 , random_state= 113)
#fit the model, codn't reqularize for illustation purposes
clf = svm.SVC(kernel = 'rbf', C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1], c =y, s = 30,cmap=plt.cm.Paired)
#plt.show()
#plt the decision function
ax = plt.gca()# shib -> finding axes
xlim = ax.get_xlim()#show the start point to the end point 
ylim = ax.get_ylim()
print(xlim)
print(ylim)
#create gird to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)#create 30 part from start poiont to end point
yy = np.linspace(ylim[0], ylim[1], 30)
# print(xx)
# print(yy)
YY, XX = np.meshgrid(yy, xx)#create matric -> like a chess
print(XX[0])
print(YY[0])
xy = np.vstack([XX.ravel(),YY.ravel()]).T#compine all of them (1,1),(1,2)
Z = clf.decision_function(xy).reshape(XX.shape)
#plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1],alpha=0.5, linestyles=['--','-','--'])
#plot support vectors
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1], s=100, linewidth = 1, facecolors = 'none')
plt.show()
# Out:
# (4.242920570385281, 10.95300051765127)
# (-11.73809442393467, 2.342055719040136)
# [4.24292057 4.24292057 4.24292057 4.24292057 4.24292057 4.24292057
#  4.24292057 4.24292057 4.24292057 4.24292057 4.24292057 4.24292057
#  4.24292057 4.24292057 4.24292057 4.24292057 4.24292057 4.24292057
#  4.24292057 4.24292057 4.24292057 4.24292057 4.24292057 4.24292057
#  4.24292057 4.24292057 4.24292057 4.24292057 4.24292057 4.24292057]
# [-11.73809442 -11.25257201 -10.76704959 -10.28152717  -9.79600475
#   -9.31048233  -8.82495991  -8.33943749  -7.85391507  -7.36839266
#   -6.88287024  -6.39734782  -5.9118254   -5.42630298  -4.94078056
#   -4.45525814  -3.96973572  -3.48421331  -2.99869089  -2.51316847
#   -2.02764605  -1.54212363  -1.05660121  -0.57107879  -0.08555637
#    0.39996604   0.88548846   1.37101088   1.8565333    2.34205572]

# %% [markdown]
# ***part 2***
